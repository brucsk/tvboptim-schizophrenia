# %% [markdown]
# #### Set up environment and import required libraries

# %%
import sys
import numpy as np
import jax
import os
import time

cpu = True
if cpu:
    N = 32
    os.environ['XLA_FLAGS'] = f'--xla_force_host_platform_device_count={N}'

# Import all required libraries
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import pandas as pd 
import jax.numpy as jnp
import copy
import optax
import scipy.io as sio
from scipy.io import loadmat
import equinox as eqx
from typing import Tuple
from itertools import product
import joblib
from joblib import Parallel, delayed
from contextlib import contextmanager
from tqdm.auto import tqdm
from pathlib import Path

# Jax enable x64
jax.config.update("jax_enable_x64", True)

# Import from tvboptim
from tvboptim.types import Parameter, BoundedParameter
from tvboptim.types.stateutils import show_parameters
from tvboptim.utils import set_cache_path, cache
from tvboptim.optim.optax import OptaxOptimizer
from tvboptim.optim.callbacks import MultiCallback, DefaultPrintCallback, SavingLossCallback

# Network dynamics imports
from tvboptim.experimental.network_dynamics import Network, solve, prepare
from tvboptim.experimental.network_dynamics.dynamics.tvb import ReducedWongWang
from tvboptim.experimental.network_dynamics.coupling.base import InstantaneousCoupling
from tvboptim.experimental.network_dynamics.coupling import LinearCoupling, FastLinearCoupling
from tvboptim.experimental.network_dynamics.graph import DenseDelayGraph, DenseGraph
from tvboptim.experimental.network_dynamics.solvers import Heun, BoundedSolver
from tvboptim.experimental.network_dynamics.noise import AdditiveNoise
from tvboptim.data import load_structural_connectivity, load_functional_connectivity
from tvboptim.experimental.network_dynamics.dynamics.base import AbstractDynamics
from tvboptim.experimental.network_dynamics.core.bunch import Bunch

# BOLD monitoring
from tvboptim.observations.tvb_monitors.bold import Bold, GammaHRFKernel, DoubleExponentialHRFKernel

# Observation functions
from tvboptim.observations.observation import compute_fc, fc_corr, rmse

# Caching utilities
from tvboptim.utils import set_cache_path, cache

# Set cache path for tvboptim
set_cache_path("ei_tuning")

# Import later built utility functions
from utils import z_score_per_region, lagged_fc_matrices
# Out:
# Cache stored here: c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\cache\ei_tuning
# Cache stored here: c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\cache\ei_tuning

# %% [markdown]
# #### Set up data for optimization

# %% [markdown]
# ##### Load time-series data

# %%
# Set up general directories 
data_dir = './' # data repo
base_dir = Path.cwd()
results_dir = os.path.join(base_dir, "results")
# Specific to this optimization run
run_folder = "HRF_test"
run_dir = os.path.join(results_dir, run_folder)
os.makedirs(run_dir, exist_ok=True)
# Set path to save simulated BOLD signal
path_simulated_bold = os.path.join(run_dir, "simulated_bold_doubleExpHRF.npy")
graph_format = 'png' # graph formatting

# %%
# data and model parameters
n_sub = 48

conds = ['CTR', 'SCZ']
n_cond = len(conds) # number of conditions

n_nodes = 68 # size of network for AAL90

simu = 0 # set to 1 if simulated data (and not empirical data)
fc0_zerodiag = 0 # set to 1 to zero out diagonal of FC matrices for optimization

if simu:
    TS_CTR  = np.load("C:\\Users\\Bruna\\Documents\\Cogmaster\\M2\\Stage\\scripts\\TVBSim\\result\\psilo_baseline_test\\BOLD_g_K_e_8.0714e+00_g_K_i_8.2143e+00_g_Na_e_1.9286e+00_g_Na_i_1.7857e+00_0_60.npy")
    TS_SCZ  = np.load("C:\\Users\\Bruna\\Documents\\Cogmaster\\M2\\Stage\\scripts\\TVBSim\\result\\psilo_baseline_test\\BOLD_g_K_e_prop_-61.8_g_K_i_prop_-64_g_Na_e_1.9286e+00_g_Na_i_1.7857e+00_0_60.npy")
    # Reshape simulated data to be (subjects, ROIs, time points) like the empirical data
    TS_CTR = np.transpose(TS_CTR, (0, 2, 1))
    TS_SCZ = np.transpose(TS_SCZ, (0, 2, 1))
    print(TS_CTR.shape)
    # Keep only 152 time points to match empirical data
    TS_CTR = TS_CTR[0:48, :, 0:152]
    TS_SCZ= TS_SCZ[0:48, :, 0:152]
    print(TS_CTR.shape)
else:
    TS_CTR  = np.load('TS_Control.npy')
    TS_SCZ  = np.load('TS_Schizo.npy')
    print(TS_CTR.shape)
# Out:
# (116, 82, 152)

# %% [markdown]
# ##### Organize time-series data

# %%
# Separate the participants by condition
condition_0 = TS_CTR[0:n_sub, 0:n_nodes, :]  # all participants (condition 0)
condition_1 = TS_SCZ[:, 0:n_nodes, :]  # Last 48 participants (condition 1)

# Determine the maximum number of participants in either condition (for alignment)
max_participants = max(condition_0.shape[2], condition_1.shape[2])

# Pad the smaller group to match the size of the larger one along the participant dimension
condition_0_padded = np.pad(condition_0, ((0, 0), (0, 0), (0, max_participants - condition_0.shape[2])), mode='constant')
condition_1_padded = np.pad(condition_1, ((0, 0), (0, 0), (0, max_participants - condition_1.shape[2])), mode='constant')

# Stack the conditions along the fourth dimension
new_array = np.stack((condition_0_padded, condition_1_padded), axis=3)

# %% [markdown]
# ##### Get the FC matrix

# %%
# Compute FC0 for all participants and conditions. shape -> (n_participants, n_conditions, n_regions, n_regions)
fc0 = np.zeros((n_sub, n_cond, n_nodes, n_nodes))
for sub in range(n_sub):
    for cond in range(n_cond):
        fc0[sub, cond] = np.corrcoef(new_array[sub,:,:,cond])

# Choose one participant and condition to visualize
conditions = {0: 'CTR', 1: 'SCZ'}
participant_idx = 0
condition_idx = 0

fc0_test = fc0[participant_idx, condition_idx, :, :]

av = plt.imshow(fc0_test, cmap='cividis')
cbar = plt.colorbar(av, fraction=0.046, pad=0.04)
plt.xticks([0, 20, 40, 60], fontsize=12)
plt.yticks([0, 20, 40, 60], fontsize=12)
plt.title(f"FC0 - Participant {participant_idx}, Condition {conditions[condition_idx]}", fontsize=16)
plt.xlabel("Region", fontsize=14)
plt.ylabel("Region", fontsize=14)
cbar.set_label("Pearson correlation coefficient", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Compute Q0 and Q1 from empirical BOLD signal
#
# **Obs**: We use the notation Q0 and Q1 for the zero lag and 1-TR lag matrices to distinguish from FC0, since they are computed with a different notation.
#
# We have the formulas for Q0 and Q1 are, respectively:
#
# $$ \hat{S_{ij}}(0) = \frac{1}{T-2} \sum_{1 le T-1} [x_i(t) - (\bar{x_i})][x_j(t) - (\bar{x_j})] $$
# $$ \hat{S_{ij}}(1) = \frac{1}{T-2} \sum_{1 le T-1} [x_i(t) - (\bar{x_i})][x_j(t+1) - (\bar{x_j})]$$

# %%
# Get empirical time series of interest 
ts = new_array[participant_idx,:,:,condition_idx]
# Take the transpose for the lagged FC matrices computation
X_emp = ts.T
print("Empirical time series shape (time points x regions):", X_emp.shape)

# Z-score the empirical time series per region
z_scored_emp = z_score_per_region(X_emp)

# Compute empirical lagged FC matrices
Q_emp = lagged_fc_matrices(z_scored_emp, n_tau=2, diag_zero=True)
Q0_emp = Q_emp[0]  # FC0 (zero-lag)
Q1_emp = Q_emp[1]  # FC1 (lag-1)
# Out:
# Empirical time series shape (time points x regions): (152, 68)

# %%
# Plot FC 0 and FC 1 for both empirical and simulated data
fig, axes = plt.subplots(1,2, figsize=(12, 10))
# FC0 - Empirical
im0 = axes[0].imshow(Q0_emp, vmin=-1, vmax=1, cmap='cividis')
axes[0].set_title('Empirical FC0 (Lag 0)')
plt.colorbar(im0, ax=axes[0], fraction=0.046, pad=0.04)
# FC1 - Empirical
im2 = axes[1].imshow(Q1_emp, vmin=-1, vmax=1, cmap='cividis')
axes[1].set_title('Empirical FC1 (Lag 1)')
plt.colorbar(im2, ax=axes[1], fraction=0.046, pad=0.04)

# %% [markdown]
# ##### Load structural connectivity data

# %%
# Weights
SCR = sio.loadmat('SC_EnigmadK68.mat')['matrix']
weights = SCR / np.max(SCR)
n_nodes = weights.shape[0]

# Delays
lengths = pd.read_csv('tract_lengths.csv')
speed = 3.0
delays = lengths / speed

# Load empirical functional connectivity as optimization target
fc_target = fc0_test
# Set target FC diagonal to zero to ignore diagonal (self-connections) during loss calculation
if fc0_zerodiag:
    fc_target = jnp.fill_diagonal(fc_target, 0.0, inplace=False)

# Load region labels and coordinates
df = pd.read_csv(
    'centers.txt',
    sep='\t',
    header=None,
    dtype={1: float, 2: float, 3: float},
    names=['label', 'x', 'y', 'z']
)

labels = df['label'].tolist()
coords = df[['x','y','z']].values

# %%
# Plot for visualization

# Define consistent color palette derived from cividis
cividis_cmap = plt.cm.cividis
cividis_colors = cividis_cmap(np.linspace(0, 1, 256))
accent_blue = cividis_cmap(0.3)  # Dark blue from cividis
accent_gold = cividis_cmap(0.85)  # Gold/yellow from cividis
accent_mid = cividis_cmap(0.6)   # Mid-tone

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(8.1, 4))

# Structural weights - use cividis
im1 = ax1.imshow(weights, cmap='cividis', vmin=0, vmax=1)
ax1.set_title('Structural Weights')
ax1.set_xlabel('Region')
ax1.set_ylabel('Region')
plt.colorbar(im1, ax=ax1, fraction=0.046)

# Delays - use cividis
im2 = ax2.imshow(delays, cmap='cividis')
ax2.set_title('Transmission Delays (ms)')
ax2.set_xlabel('Region')
ax2.set_ylabel('Region')
plt.colorbar(im2, ax=ax2, fraction=0.046, label='ms')

# Target FC - use cividis
im3 = ax3.imshow(fc_target, vmin=0, vmax=1.0, cmap='cividis')
ax3.set_title('Target Functional Connectivity')
ax3.set_xlabel('Region')
ax3.set_ylabel('Region')
plt.colorbar(im3, ax=ax3, label='Correlation', fraction=0.046)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Define the model to optimize

# %%
class ReducedWongWangEIB(AbstractDynamics):
    """Two-population Reduced Wong-Wang model with E-I balance support"""

    STATE_NAMES = ('S_e', 'S_i')
    INITIAL_STATE = (0.001, 0.001)
    AUXILIARY_NAMES = ('H_e', 'H_i')
    g_prop = 0  # awake

    DEFAULT_PARAMS = Bunch(
        # Excitatory population parameters
        a_e=310.0,         # Input gain parameter
        b_e=125.0,         # Input shift parameter [Hz]
        d_e=0.160,         # Input scaling parameter [s]
        gamma_e=0.641/1000,  # Kinetic parameter
        tau_e=100.0,       # NMDA decay time constant [ms]
        w_p   = 1.4 * (1 - 0.2*g_prop),           # Excitatory recurrence weight
        W_e=1.0,           # External input scaling weight

        # Inhibitory population parameters
        a_i=615.0,         # Input gain parameter
        b_i=177.0,         # Input shift parameter [Hz]
        d_i=0.087,         # Input scaling parameter [s]
        gamma_i=1.0/1000,  # Kinetic parameter
        tau_i = 10  * (1 + 0.8*g_prop),        # NMDA decay time constant [ms]
        W_i=0.7,           # External input scaling weight

        # Synaptic weights
        J_N=0.15,          # NMDA current [nA]
        J_i   = 1.0 * (1 + 0.6*g_prop),          # Inhibitory synaptic weight

        # External inputs
        I_o=0.382,         # Background input current
        I_ext=0.0,         # External stimulation current

        # Coupling parameters
        lamda=1.0,         # Lambda: inhibitory coupling scaling

    )

# Primary GABA effect
#J_i = 1.0 → 1.4
# Slower inhibition
#tau_i = 10.0 → 18.0
# Slightly reduced excitation
#w_p = 1.4 → 1.2

    COUPLING_INPUTS = {
        'coupling': 2,  # Long-range excitation and Feedforward inhibition
    }

    def dynamics(
        self,
        t: float,
        state: jnp.ndarray,
        params: Bunch,
        coupling: Bunch,
        external: Bunch
    ) -> Tuple[jnp.ndarray, jnp.ndarray]:
        """Compute two-population Wong-Wang dynamics with dual coupling."""

        # Unpack state variables
        S_e = state[0]  # Excitatory synaptic gating
        S_i = state[1]  # Inhibitory synaptic gating

        # Unpack coupling inputs
        c_lre = params.J_N * coupling.coupling[0]  # Long-range excitation
        c_ffi = params.J_N * coupling.coupling[1]  # Feedforward inhibition

        # Excitatory population input
        J_N_S_e = params.J_N * S_e
        x_e_pre = (params.w_p * J_N_S_e - params.J_i * S_i +
                   params.W_e * params.I_o + c_lre + params.I_ext)

        # Excitatory transfer function
        x_e = params.a_e * x_e_pre - params.b_e
        H_e = x_e / (1.0 - jnp.exp(-params.d_e * x_e))

        # Excitatory dynamics
        dS_e_dt = -(S_e / params.tau_e) + (1.0 - S_e) * H_e * params.gamma_e

        # Inhibitory population input
        x_i_pre = J_N_S_e - S_i + params.W_i * params.I_o + params.lamda * c_ffi

        # Inhibitory transfer function
        x_i = params.a_i * x_i_pre - params.b_i
        H_i = x_i / (1.0 - jnp.exp(-params.d_i * x_i))

        # Inhibitory dynamics
        dS_i_dt = -(S_i / params.tau_i) + H_i * params.gamma_i

        # Package results
        derivatives = jnp.array([dS_e_dt, dS_i_dt])
        auxiliaries = jnp.array([H_e, H_i])

        return derivatives, auxiliaries
    
class EIBLinearCoupling(InstantaneousCoupling):
    """EIB Linear coupling with separate excitatory and inhibitory weight matrices.

    This coupling produces two outputs:
        c_lre: Long-range excitation (wLRE * S_e)
        c_ffi: Feedforward inhibition (wFFI * S_e)

    Both couplings are driven by the excitatory activity (S_e) from other regions.
    """

    N_OUTPUT_STATES = 2  # Produces two coupling outputs

    DEFAULT_PARAMS = Bunch(
        wLRE = 1.0,  # Long-range excitation weight matrix
        wFFI = 1.0,  # Feedforward inhibition weight matrix
    )

    def pre(
        self,
        incoming_states: jnp.ndarray,
        local_states: jnp.ndarray,
        params: Bunch
    ) -> jnp.ndarray:
        """Pre-synaptic transformation: multiply S_e with wLRE and wFFI."""
        # incoming_states[0] is S_e from all source nodes
        S_e = incoming_states[0]  # [n_target, n_source]
        # Apply weights: element-wise multiply S_e with each weight matrix
        # params.wLRE and params.wFFI have shape [n_nodes, n_nodes]
        c_lre = S_e * params.wLRE  # [n_target, n_source]
        c_ffi = S_e * params.wFFI  # [n_target, n_source]

        # Stack into [2, n_target, n_source]
        return jnp.stack([c_lre, c_ffi], axis=0)

    def post(
        self,
        summed_inputs: jnp.ndarray,
        local_states: jnp.ndarray,
        params: Bunch
    ) -> jnp.ndarray:
        """Post-synaptic transformation: pass through without scaling."""
        return summed_inputs

# %% [markdown]
# #### Building the network model

# %%
# Create network components
graph = DenseGraph(weights, region_labels=labels)
dynamics = ReducedWongWangEIB(J_i = jnp.ones((n_nodes)))

# Initialize EIB coupling with dual weight matrices
# wLRE and wFFI start as copies of structural connectivity
coupling = EIBLinearCoupling(incoming_states=["S_e"])

# Set the weight matrices to the proper shape based on structural connectivity
# Both start as scaled versions of structural connectivity
coupling.params.wLRE = jnp.ones((n_nodes, n_nodes)) #+ 0.8*fc_target  # [n_nodes, n_nodes]
coupling.params.wFFI = jnp.ones((n_nodes, n_nodes)) #- 0.8*fc_target  # [n_nodes, n_nodes]

# Small noise to break symmetry
noise = AdditiveNoise(sigma=0.01, apply_to="S_e")

# Assemble the network
network = Network(
    dynamics=dynamics,
    coupling={'coupling': coupling},  # Both use same coupling but produce different outputs
    graph=graph,
    noise=noise
)

print(f"Network created with {n_nodes} nodes")
# Out:
# Network created with 68 nodes

# %% [markdown]
# #### Initial simulation

# %%
# Prepare simulation: compile model and initialize state
t1 = 314_000   # Simulation duration (ms) - 1 minute for initial transient
dt = 4.0      # Integration timestep (ms) matching original script
solver = BoundedSolver(Heun(), low=0.0, high=1.0)
model, state = prepare(network, solver, t1=t1, dt=dt)

# Run initial transient to reach quasi-stationary state
print("Running initial transient simulation...")
result_init = jax.block_until_ready(model(state))

# Update network with final state as new initial conditions
network.update_history(result_init)

# Prepare for shorter simulations used in EI tuning
bold_TR = 2000.0
model_short, state_short = prepare(network, solver, t1=bold_TR, dt=dt)

print(f"Initial simulation complete. Final S_e mean: {result_init.data[-1, 0, :].mean():.3f}")
print(f"Initial simulation complete. Final S_i mean: {result_init.data[-1, 1, :].mean():.3f}")
# Out:
# Running initial transient simulation...
# Initial simulation complete. Final S_e mean: 0.856
# Initial simulation complete. Final S_i mean: 0.949

# %% [markdown]
# #### Create BOLD monitor for evaluation

# %%
# Create BOLD monitor - we'll monitor S_e (first state variable)
# The BOLD period is bold_TR
bold_monitor = Bold(
    period=bold_TR,           # BOLD sampling period (TR = 2000 ms)
    downsample_period=4.0,  # Intermediate downsampling matches dt
    voi=0,                  # Monitor first state variable (S_e)
    history=result_init,     # Use initial state as warm start for BOLD history
    kernel=DoubleExponentialHRFKernel()
)

print("BOLD monitor initialized")
# Out:
# BOLD monitor initialized

# %% [markdown]
# #### Utility functions

# %%
# Will be populated after initial simulation completes
model_eval, state_eval, _state = None, None, None

def setup_eval_model():
    """Setup evaluation model for FC computation (called after initial simulation)."""
    global model_eval, state_eval, _state
    model_eval, state_eval = prepare(network, Heun(), t1=t1, dt=dt)
    _state = copy.deepcopy(state_eval)

def eval_fc(J_i, wLRE, wFFI):
    """Evaluate FC for given parameters using a long simulation."""
    _state.dynamics.J_i = J_i
    _state.coupling.coupling.wLRE = wLRE
    _state.coupling.coupling.wFFI = wFFI

    # Run simulation
    raw_result = model_eval(_state)

    # Compute BOLD
    bold_signal = bold_monitor(raw_result)

    # Compute FC (skip initial transient)
    fc = compute_fc(bold_signal, skip_t=20)
    return fc

# %% [markdown]
# #### Gradient-based optimization approach

# %%
# Prepare simulation
t1_opt = 314_000 # Simulation duration (ms) 
dt_opt = 4.0
solver_opt = BoundedSolver(Heun(), low=0.0, high=1.0)
model_opt, state_opt = prepare(network, solver_opt, t1=t1_opt, dt=dt_opt)

# FIC tuning parameter
target_fic = 0.25  # Target excitatory activity level

# Create BOLD monitor
bold_monitor_opt = Bold(
    period=bold_TR,
    downsample_period=4.0,
    voi=0,
    history=result_init,
    kernel=DoubleExponentialHRFKernel()
)

print("Optimization model prepared")

# Define loss function for optimization 
beta_fc1 = 2.0 # Weight for FC1 loss component
alpha_fc0 = 1.0 # Weight for FC0 loss component

def loss(state):
    ts = model_opt(state)
    bold = bold_monitor_opt(ts)

    bold_signal = bold.data
    n_timepoints, n_nodes = bold_signal.shape[0], bold_signal.shape[-1]
    bold_signal = bold_signal.reshape(n_timepoints, n_nodes)
    bold_signal = bold_signal[5:, :]
    z_scored_bold = z_score_per_region(bold_signal)

    Qsim = lagged_fc_matrices(z_scored_bold, n_tau=2, diag_zero=True)
    Q0_sim, Q1_sim = Qsim[0], Qsim[1]

    loss_q0 = rmse(Q0_sim, Q0_emp)
    loss_q1 = rmse(Q1_sim, Q1_emp)

    mean_activity = jnp.mean(ts.data[-500:, 0, :], axis=0)
    activity_loss = jnp.mean((mean_activity - target_fic) ** 2)

    return alpha_fc0 * loss_q0 + beta_fc1 * loss_q1 + activity_loss
##

# Evaluate initial loss
initial_loss = loss(state_opt)
print(f"Initial loss: {initial_loss:.4f}")

# Mark parameters for optimization (J_i, wLRE, wFFI) with appropriate constraints
state_opt.dynamics.J_i = Parameter(state_opt.dynamics.J_i)
state_opt.coupling.coupling.wLRE = BoundedParameter(jnp.ones((n_nodes, n_nodes)), low=0.0, high=jnp.inf)
state_opt.coupling.coupling.wFFI = BoundedParameter(jnp.ones((n_nodes, n_nodes)), low=0.0, high=jnp.inf)

# Define gradient optimization function 
@cache("gradient_optimization", redo=True)
def run_gradient_optimization(
    max_steps: int,
    learning_rate: float,
    lr_schedule: str = "constant",
    cosine_alpha: float = 0.0,
    cosine_decay_steps: int | None = 40,
    verbose: bool = True,
):
    """Run gradient-based optimization with optional LR scheduling.

    Parameters
    ----------
    max_steps : int
        Number of optimization steps.
    learning_rate : float
        Initial learning rate.
    lr_schedule : str
        "constant" or "cosine".
    cosine_alpha : float
        Final LR fraction for cosine decay (0.0 means decays to 0).
    cosine_decay_steps : int or None
        Number of decay steps for cosine schedule. If None, uses max_steps.
    verbose : bool
        Whether to print schedule information.
    """

    # Choose learning rate: fixed scalar or cosine-decay schedule
    if lr_schedule == "cosine":
        decay_steps = max_steps if cosine_decay_steps is None else int(cosine_decay_steps)
        lr = optax.cosine_decay_schedule(
            init_value=learning_rate,
            decay_steps=decay_steps,
            alpha=cosine_alpha,
        )
        if verbose:
            print(
                f"Using cosine LR: init={learning_rate}, decay_steps={decay_steps}, alpha={cosine_alpha}"
            )
    elif lr_schedule == "constant":
        lr = learning_rate
        if verbose:
            print(f"Using constant LR: {learning_rate}")
    else:
        raise ValueError("lr_schedule must be 'constant' or 'cosine'")

    # Create optimizer
    optimizer = OptaxOptimizer(
        loss,
        optax.adamaxw(learning_rate=lr),
        callback=MultiCallback([DefaultPrintCallback(), SavingLossCallback()])
    )

    # Run optimization
    opt_state, opt_fitting_data = optimizer.run(state_opt, max_steps=max_steps)

    return opt_state, opt_fitting_data

def compute_fc_from_state(opt_state):
    """Compute FC from a given optimization state."""
    return eval_fc(
        opt_state.dynamics.J_i,
        opt_state.coupling.coupling.wLRE,
        opt_state.coupling.coupling.wFFI
    )

def evaluate_trial(opt_state):
    """ Evaluate a single trial and return metrics."""
    fc_opt = compute_fc_from_state(opt_state)

    # Compute quality metrics
    corr_val = fc_corr(fc_opt, fc_target)
    rmse_val = rmse(fc_opt, fc_target)
    return {
        "corr": float(jnp.nan_to_num(corr_val, nan=-jnp.inf)),
        "rmse": float(jnp.nan_to_num(rmse_val, nan=jnp.inf)),
    }

def evaluate_trial_grid(lr: float, steps: int, verbose=False):
    """ Evaluate a single trial with given hyperparameters and return metrics. To use when running a grid search. """
    opt_state, _ = run_gradient_optimization(learning_rate=lr, max_steps=steps)
    evaluate_dict = evaluate_trial(opt_state)
    if verbose:
        print(f"Trial (lr={lr:.4f}, steps={steps}): corr={evaluate_dict['corr']:.4f}, rmse={evaluate_dict['rmse']:.4f}")
    evaluate_dict.update({ "lr": lr, "steps": steps })
    return evaluate_dict

#  Setup evaluation model
setup_eval_model()

# Compute FC before gradient descent optimization
print("Computing pre-gradient descent functional connectivity...")

fc_pre_gd, fc_corr_pre, fc_rmse_pre = compute_fc_from_state(state_opt), evaluate_trial(state_opt)["corr"], evaluate_trial(state_opt)["rmse"]
# Out:
# Optimization model prepared
# Initial loss: 1.0405
# Computing pre-gradient descent functional connectivity...

# %% [markdown]
# ##### Set parameters for gradient descent

# %%
# Hyperparameters
max_steps = 120
learning_rate = 0.0325

# %% [markdown]
# ##### Run gradient optimization

# %%
optimized_state, fitting_data = run_gradient_optimization(max_steps = max_steps, learning_rate = learning_rate)
# Out:
# Running computations for gradient_optimization
# Using constant LR: 0.0325
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File <frozen runpy>:198, in _run_module_as_main()
#
# File <frozen runpy>:88, in _run_code()
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\ipykernel_launcher.py:18
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\traitlets\config\application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\ipykernel\kernelapp.py:758, in start()
#     757 try:
# --> 758     self.io_loop.start()
#     759 except KeyboardInterrupt:
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\tornado\platform\asyncio.py:211, in start()
#     210 def start(self) -> None:
# --> 211     self.asyncio_loop.run_forever()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:608, in run_forever()
#     607 while True:
# --> 608     self._run_once()
#     609     if self._stopping:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:1936, in _run_once()
#    1935     else:
# -> 1936         handle._run()
#    1937 handle = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\events.py:84, in _run()
#      83 try:
# ---> 84     self._context.run(self._callback, *self._args)
#      85 except (SystemExit, KeyboardInterrupt):
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\ipykernel\kernelbase.py:621, in shell_main()
#     620 async with asyncio_lock:
# --> 621     await self.dispatch_shell(msg, subshell_id=subshell_id)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\ipykernel\kernelbase.py:478, in dispatch_shell()
#     477     if inspect.isawaitable(result):
# --> 478         await result
#     479 except Exception:
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\ipykernel\ipkernel.py:372, in execute_request()
#     371 """Override for cell output - cell reconciliation."""
# --> 372 await super().execute_request(stream, ident, parent)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\ipykernel\kernelbase.py:834, in execute_request()
#     833 if inspect.isawaitable(reply_content):
# --> 834     reply_content = await reply_content
#     835 else:
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\ipykernel\ipkernel.py:464, in do_execute()
#     463 if accepts_params["cell_id"]:
# --> 464     res = shell.run_cell(
#     465         code,
#     466         store_history=store_history,
#     467         silent=silent,
#     468         cell_id=cell_id,
#     469     )
#     470 else:
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\ipykernel\zmqshell.py:663, in run_cell()
#     662 self._last_traceback = None
# --> 663 return super().run_cell(*args, **kwargs)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3123, in run_cell()
#    3122 try:
# -> 3123     result = self._run_cell(
#    3124         raw_cell, store_history, silent, shell_futures, cell_id
#    3125     )
#    3126 finally:
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3178, in _run_cell()
#    3177 try:
# -> 3178     result = runner(coro)
#    3179 except BaseException as e:
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner()
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3400, in run_cell_async()
#    3397 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3400 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3401        interactivity=interactivity, compiler=compiler, result=result)
#    3403 self.last_execution_succeeded = not has_raised
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3641, in run_ast_nodes()
#    3640     asy = compare(code)
# -> 3641 if await self.run_code(code, result, async_=asy):
#    3642     return True
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3701, in run_code()
#    3700     else:
# -> 3701         exec(code_obj, self.user_global_ns, self.user_ns)
#    3702 finally:
#    3703     # Reset our crash handler in place
#
# Cell In[23], line 1
# ----> 1 optimized_state, fitting_data = run_gradient_optimization(max_steps = max_steps, learning_rate = learning_rate)
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\utils\caching.py:69, in wrapper()
#      68 print(f"Running computations for {fname}")
# ---> 69 comp = func(*args, **kwargs)
#      70 if caching:
#
# Cell In[19], line 111, in run_gradient_optimization()
#     110 # Run optimization
# --> 111 opt_state, opt_fitting_data = optimizer.run(state_opt, max_steps=max_steps)
#     113 return opt_state, opt_fitting_data
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\optim\optax.py:213, in run()
#     212 for i in range(max_steps):
# --> 213     diff_state, grads, opt_state, loss_value, aux_data = step(
#     214         diff_state, static_state, opt_state
#     215     )
#     216     # print(format_pytree_as_string(diff_state, hide_none=True, name="FreeState", show_array_values=True))
#     217     # print(format_pytree_as_string(diff_state, hide_none=True, name="FreeState", show_array_values=True))
#     218     # fitting_data.append(diff_state)
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\optim\optax.py:191, in step()
#     189 def step(diff_state, static_state, opt_state):
#     190     # out = value_and_grad(_loss, argnums=0, has_aux=self.has_aux)(diff_state, static_state)
# --> 191     out = v_g_fun(diff_state, static_state)
#     192     (loss_value, aux_data), grads = out
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\optim\optax.py:173, in _fun()
#     172 def _fun(*args, **kwargs):
# --> 173     val, grads = vgf(*args, **kwargs)
#     174     return (val, None), grads
#
# JaxStackTraceBeforeTransformation: KeyboardInterrupt
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 optimized_state, fitting_data = run_gradient_optimization(max_steps = max_steps, learning_rate = learning_rate)
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\utils\caching.py:69, in cache.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      67 else:
#      68     print(f"Running computations for {fname}")
# ---> 69     comp = func(*args, **kwargs)
#      70     if caching:
#      71         if not os.path.exists(cache_path):
#
# Cell In[19], line 111, in run_gradient_optimization(max_steps, learning_rate, lr_schedule, cosine_alpha, cosine_decay_steps, verbose)
#     104 optimizer = OptaxOptimizer(
#     105     loss,
#     106     optax.adamaxw(learning_rate=lr),
#     107     callback=MultiCallback([DefaultPrintCallback(), SavingLossCallback()])
#     108 )
#     110 # Run optimization
# --> 111 opt_state, opt_fitting_data = optimizer.run(state_opt, max_steps=max_steps)
#     113 return opt_state, opt_fitting_data
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\optim\optax.py:213, in OptaxOptimizer.run(self, state, max_steps, mode)
#     211 fitting_data = dict()  # store data during fitting
#     212 for i in range(max_steps):
# --> 213     diff_state, grads, opt_state, loss_value, aux_data = step(
#     214         diff_state, static_state, opt_state
#     215     )
#     216     # print(format_pytree_as_string(diff_state, hide_none=True, name="FreeState", show_array_values=True))
#     217     # print(format_pytree_as_string(diff_state, hide_none=True, name="FreeState", show_array_values=True))
#     218     # fitting_data.append(diff_state)
#     219     if self.callback is not None:
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\optim\optax.py:191, in OptaxOptimizer.run.<locals>.step(diff_state, static_state, opt_state)
#     189 def step(diff_state, static_state, opt_state):
#     190     # out = value_and_grad(_loss, argnums=0, has_aux=self.has_aux)(diff_state, static_state)
# --> 191     out = v_g_fun(diff_state, static_state)
#     192     (loss_value, aux_data), grads = out
#     194     # if self.has_aux:
#     195     #     (loss_value, aux_data), grads = out
#     196     # else:
#     197     #     loss_value, grads = out
#     198     #     aux_data = None
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\optim\optax.py:173, in OptaxOptimizer.run.<locals>.value_and_grad.<locals>._fun(*args, **kwargs)
#     172 def _fun(*args, **kwargs):
# --> 173     val, grads = vgf(*args, **kwargs)
#     174     return (val, None), grads
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\api.py:483, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     481 _check_scalar(ans)
#     482 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 483 g = vjp_py(lax_internal._one(ans))
#     484 g = g[0] if isinstance(argnums, int) else g
#     485 if not has_aux:
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\tree_util.py:510, in _HashableCallableShim.__call__(self, *args, **kw)
#     509 def __call__(self, *args, **kw):
# --> 510   return self.fun(*args, **kw)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\api.py:2053, in _vjp_pullback_wrapper(name, out_primal_avals, io_tree, fun, *py_args_)
#    2046   if (not core.typecompat(ct_aval, ct_aval_expected) and
#    2047       not _temporary_dtype_exception(ct_aval, ct_aval_expected)):
#    2048     raise ValueError(
#    2049         "unexpected JAX type (e.g. shape/dtype) for argument to vjp function: "
#    2050         f"got {ct_aval.str_short()}, but expected {ct_aval_expected.str_short()} "
#    2051         f"because the corresponding output of the function {name} had JAX type "
#    2052         f"{aval.str_short()}")
# -> 2053 ans = fun(*args)
#    2054 return tree_unflatten(out_tree, ans)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\tree_util.py:510, in _HashableCallableShim.__call__(self, *args, **kw)
#     509 def __call__(self, *args, **kw):
# --> 510   return self.fun(*args, **kw)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\interpreters\ad.py:320, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     318 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     319 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 320 arg_cts = backward_pass(jaxpr, True, consts, dummy_args, cts)
#     321 return map(instantiate_zeros, arg_cts)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\interpreters\ad.py:438, in backward_pass(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     436 else:
#     437   try:
# --> 438     cts_out = get_primitive_transpose(eqn.primitive)(
#     439         cts_in, *invals, **eqn.params)
#     440   except core.ShardingTypeError as e:
#     441     extra_msg = ("This is a potential JAX bug. Please file an issue at"
#     442                  " https://github.com/jax-ml/jax/issues")
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\pjit.py:2526, in _pjit_transpose(cts_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *primals_in)
#    2520 transpose_out_layouts = prune_type(
#    2521     ad.Zero,
#    2522     in_layouts,
#    2523     tree_unflatten(cts_out_treedef, [object()] * cts_out_treedef.num_leaves))
#    2525 try:
# -> 2526   nz_cts_out = jit_p.bind(
#    2527       *primals_and_nz_cts_in,
#    2528       jaxpr=transpose_jaxpr,
#    2529       in_shardings=transpose_in_shardings,
#    2530       out_shardings=transpose_out_shardings,
#    2531       in_layouts=transpose_in_layouts,
#    2532       out_layouts=transpose_out_layouts,
#    2533       donated_invars=(False,) * len(primals_and_nz_cts_in),
#    2534       ctx_mesh=ctx_mesh,
#    2535       name=name,
#    2536       keep_unused=keep_unused,
#    2537       inline=inline,
#    2538       compiler_options_kvs=compiler_options_kvs)
#    2539 except api_util.InternalFloatingPointError as e:
#    2540   print("Invalid nan value encountered in the backward pass of a jax.jit "
#    2541         "function. Calling the de-optimized backward pass.")
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\core.py:634, in Primitive.bind(self, *args, **params)
#     632 def bind(self, *args, **params):
#     633   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 634   return self._true_bind(*args, **params)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\core.py:650, in Primitive._true_bind(self, *args, **params)
#     648 trace_ctx.set_trace(eval_trace)
#     649 try:
# --> 650   return self.bind_with_trace(prev_trace, args, params)
#     651 finally:
#     652   trace_ctx.set_trace(prev_trace)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\core.py:662, in Primitive.bind_with_trace(self, trace, args, params)
#     660     with set_current_trace(trace):
#     661       return self.to_lojax(*args, **params)  # type: ignore
# --> 662   return trace.process_primitive(self, args, params)
#     663 trace.process_primitive(self, args, params)  # may raise lojax error
#     664 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\core.py:1189, in EvalTrace.process_primitive(self, primitive, args, params)
#    1187 args = map(full_lower, args)
#    1188 check_eval_args(args)
# -> 1189 return primitive.impl(*args, **params)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\pjit.py:1829, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1821 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1822 cache_key = pxla.JitGlobalCppCacheKeys(
#    1823     donate_argnums=donated_argnums, donate_argnames=None,
#    1824     device=None, backend=None,
#    (...)   1827     in_layouts_treedef=None, in_layouts_leaves=in_layouts,
#    1828     out_layouts_treedef=None, out_layouts_leaves=out_layouts)
# -> 1829 return xc._xla.pjit(
#    1830     name, f, call_impl_cache_miss, [], [], cache_key,
#    1831     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1832     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\pjit.py:1805, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1801 def call_impl_cache_miss(*args_, **kwargs_):
#    1802   # args_ do not include the const args
#    1803   # See https://docs.jax.dev/en/latest/internals/constants.html.
#    1804   # TODO(necula): remove num_const_args when fixing the C++ path
# -> 1805   out_flat, compiled, pgle_profiler, const_args = _pjit_call_impl_python(
#    1806       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1807       out_shardings=out_shardings, in_layouts=in_layouts,
#    1808       out_layouts=out_layouts, donated_invars=donated_invars,
#    1809       ctx_mesh=ctx_mesh, name=name, keep_unused=keep_unused,
#    1810       inline=inline, compiler_options_kvs=compiler_options_kvs)
#    1811   fastpath_data = _get_fastpath_data(
#    1812       compiled, tree_structure(out_flat), args, out_flat,
#    1813       jaxpr.effects, jaxpr.consts, None, pgle_profiler,
#    1814       const_args)
#    1815   return out_flat, fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\pjit.py:1758, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1746 # Passing mutable PGLE profile here since it should be extracted by JAXPR to
#    1747 # initialize the fdo_profile compile option.
#    1748 computation = _resolve_and_lower(
#    1749     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1750     out_shardings=out_shardings, in_layouts=in_layouts,
#    (...)   1756     compiler_options_kvs=compiler_options_kvs,
#    1757 )
# -> 1758 compiled = computation.compile()
#    1760 # This check is expensive so only do it if enable_checks is on.
#    1761 if compiled._auto_spmd_lowering and config.enable_checks.value:
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\interpreters\pxla.py:2537, in MeshComputation.compile(self, compiler_options, device_assignment)
#    2534 assert isinstance(compilation_device_list, (type(None), xc.DeviceList))
#    2536 if self._executable is None or compiler_options_kvs or device_assignment:
# -> 2537   executable = UnloadedMeshExecutable.from_hlo(
#    2538       self._name, self._hlo, **self.compile_args,
#    2539       compiler_options_kvs=compiler_options_kvs,
#    2540       device_list=compilation_device_list)
#    2541   if not compiler_options_kvs:
#    2542     self._executable = executable
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\interpreters\pxla.py:3083, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    3080       break
#    3082 util.test_event("pxla_cached_compilation")
# -> 3083 xla_executable = _cached_compilation(
#    3084     hlo, name, mesh, spmd_lowering,
#    3085     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    3086     allow_prop_to_outputs, tuple(host_callbacks), backend, device_list,
#    3087     pmap_nreps, compiler_options_kvs, pgle_profiler)
#    3089 if auto_spmd_lowering:
#    3090   assert mesh is not None
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\interpreters\pxla.py:2864, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_kvs, pgle_profiler)
#    2856 compile_options = create_compile_options(
#    2857     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2858     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2859     dev, pmap_nreps, compiler_options)
#    2861 with dispatch.log_elapsed_time(
#    2862     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2863     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2864   xla_executable = compiler.compile_or_get_cached(
#    2865       backend, computation, dev, compile_options, host_callbacks,
#    2866       da, pgle_profiler)
#    2867 return xla_executable
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\compiler.py:494, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, executable_devices, pgle_profiler)
#     492 else:
#     493   log_persistent_cache_miss(module_name, cache_key)
# --> 494   return _compile_and_write_cache(
#     495       backend,
#     496       computation,
#     497       executable_devices,
#     498       compile_options,
#     499       host_callbacks,
#     500       module_name,
#     501       cache_key,
#     502   )
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\compiler.py:762, in _compile_and_write_cache(backend, computation, executable_devices, compile_options, host_callbacks, module_name, cache_key)
#     752 def _compile_and_write_cache(
#     753     backend: xc.Client,
#     754     computation: ir.Module,
#    (...)    759     cache_key: str,
#     760 ) -> xc.LoadedExecutable:
#     761   start_time = time.monotonic()
# --> 762   executable = backend_compile_and_load(
#     763       backend, computation, executable_devices, compile_options, host_callbacks
#     764   )
#     765   compile_time = time.monotonic() - start_time
#     766   _cache_write(
#     767       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     768   )
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\profiler.py:364, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     361 @wraps(func)
#     362 def wrapper(*args, **kwargs):
#     363   with TraceAnnotation(name, **decorator_kwargs):
# --> 364     return func(*args, **kwargs)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\compiler.py:378, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     369       return backend.compile_and_load(
#     370           built_c,
#     371           executable_devices=executable_devices,
#     372           compile_options=options,
#     373           host_callbacks=host_callbacks,
#     374       )
#     375     # Some backends don't have `host_callbacks` option yet
#     376     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     377     # to take in `host_callbacks`
# --> 378     return backend.compile_and_load(
#     379         built_c,
#     380         executable_devices=executable_devices,
#     381         compile_options=options,
#     382     )
#     383 except xc.XlaRuntimeError as e:
#     384   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %%
fc_opt = compute_fc_from_state(optimized_state)
fc_corr_opt = evaluate_trial(optimized_state)['corr']
fc_rmse_opt = evaluate_trial(optimized_state)['rmse']

print(f"\nOptimization Results:")
print(f"  Pre-Optimization  - Correlation: {fc_corr_pre:.4f}, RMSE: {fc_rmse_pre:.4f}")
print(f"  Post-Optimization - Correlation: {fc_corr_opt:.4f}, RMSE: {fc_rmse_opt:.4f}")
print(f"  Improvement: Δcorr = {fc_corr_opt - fc_corr_pre:+.4f}, ΔRMSE = {fc_rmse_opt - fc_rmse_pre:+.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 fc_opt = compute_fc_from_state(optimized_state)
#       2 fc_corr_opt = evaluate_trial(optimized_state)['corr']
#       3 fc_rmse_opt = evaluate_trial(optimized_state)['rmse']
#
# NameError: name 'optimized_state' is not defined

# %% [markdown]
# ##### Plot results

# %%
# Extract loss values
loss_values = fitting_data["loss"].save
n_steps = len(loss_values)

fig = plt.figure(figsize=(8.1, 6))
gs = fig.add_gridspec(2, 3, hspace=0.3, wspace=0.4)

# Top left: Loss trajectory - use cividis-derived colors
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(loss_values, linewidth=2, color="k", alpha=0.9)
ax1.scatter(0, loss_values[0], s=80, color=accent_blue, zorder=5)
ax1.scatter(n_steps-1, loss_values.array[-1], s=80, color=accent_gold, zorder=5)
ax1.set_xlabel('Optimization Step')
ax1.set_ylabel('Combined Loss')
ax1.set_title('Loss Convergence')
ax1.grid(True, alpha=0.3)

# Top middle: wFFI matrix - use cividis
ax2 = fig.add_subplot(gs[0, 1])
im2 = ax2.imshow(optimized_state.coupling.coupling.wFFI, vmin=0, vmax=2, cmap='cividis')
ax2.set_title('Optimized wFFI')
ax2.set_xlabel('Source')
ax2.set_ylabel('Target')
plt.colorbar(im2, ax=ax2, fraction=0.046)

# Top right: wLRE matrix - use cividis
ax3 = fig.add_subplot(gs[0, 2])
im3 = ax3.imshow(optimized_state.coupling.coupling.wLRE, vmin=0, vmax=2, cmap='cividis')
ax3.set_title('Optimized wLRE')
ax3.set_xlabel('Source')
ax3.set_ylabel('Target')
plt.colorbar(im3, ax=ax3, fraction=0.046)

# Bottom row: FC comparison - use cividis
ax4 = fig.add_subplot(gs[1, 0])
im4 = ax4.imshow(fc_target, vmin=-1, vmax=1.0, cmap='cividis')
ax4.set_title('Target FC')
plt.colorbar(im4, ax=ax4, fraction=0.046)

ax5 = fig.add_subplot(gs[1, 1])
im5 = ax5.imshow(fc_pre_gd, vmin=-1, vmax=1.0, cmap='cividis')
ax5.set_title(f'Pre-Opt FC\nCorr: {fc_corr_pre:.3f}')
plt.colorbar(im5, ax=ax5, fraction=0.046)

ax6 = fig.add_subplot(gs[1, 2])
im6 = ax6.imshow(fc_opt + np.eye(fc_opt.shape[0]), vmin=-1, vmax=1.0, cmap='cividis')
ax6.set_title(f'Post-Opt FC\nCorr: {fc_corr_opt:.3f}')
plt.colorbar(im6, ax=ax6, fraction=0.046)

plt.show()

# %% [markdown]
# ### Test

# %%
# Single loss with heavier FC1
beta_fc1 = 2.0
alpha_fc0 = 1.0

def loss(state):
    ts = model_opt(state)
    bold = bold_monitor_opt(ts)

    bold_signal = bold.data
    n_timepoints, n_nodes = bold_signal.shape[0], bold_signal.shape[-1]
    bold_signal = bold_signal.reshape(n_timepoints, n_nodes)
    bold_signal = bold_signal[5:, :]
    z_scored_bold = z_score_per_region(bold_signal)

    Qsim = lagged_fc_matrices(z_scored_bold, n_tau=2, diag_zero=True)
    Q0_sim, Q1_sim = Qsim[0], Qsim[1]

    loss_q0 = rmse(Q0_sim, Q0_emp)
    loss_q1 = rmse(Q1_sim, Q1_emp)

    mean_activity = jnp.mean(ts.data[-500:, 0, :], axis=0)
    activity_loss = jnp.mean((mean_activity - target_fic) ** 2)

    return alpha_fc0 * loss_q0 + beta_fc1 * loss_q1 + activity_loss

# %%
optimizer_test = OptaxOptimizer(
    loss,
    optax.adamaxw(learning_rate=learning_rate),
    callback=MultiCallback([DefaultPrintCallback(), SavingLossCallback()])
)

optimized_state, optimized_fit = optimizer_test.run(state_opt, max_steps=max_steps)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 7
#       1 optimizer_test = OptaxOptimizer(
#       2     loss,
#       3     optax.adamaxw(learning_rate=learning_rate),
#       4     callback=MultiCallback([DefaultPrintCallback(), SavingLossCallback()])
#       5 )
# ----> 7 optimized_state, optimized_fit = optimizer_test.run(state_opt, max_steps=max_steps)
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\optim\optax.py:213, in OptaxOptimizer.run(self, state, max_steps, mode)
#     211 fitting_data = dict()  # store data during fitting
#     212 for i in range(max_steps):
# --> 213     diff_state, grads, opt_state, loss_value, aux_data = step(
#     214         diff_state, static_state, opt_state
#     215     )
#     216     # print(format_pytree_as_string(diff_state, hide_none=True, name="FreeState", show_array_values=True))
#     217     # print(format_pytree_as_string(diff_state, hide_none=True, name="FreeState", show_array_values=True))
#     218     # fitting_data.append(diff_state)
#     219     if self.callback is not None:
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\optim\optax.py:202, in OptaxOptimizer.run.<locals>.step(diff_state, static_state, opt_state)
#     199 def f(p):
#     200     return _loss(diff_state, static_state)
# --> 202 updates, opt_state = self.optimizer.update(
#     203     grads, opt_state, diff_state, value=loss_value, grad=grads, value_fn=f
#     204 )
#     206 diff_state = optax.apply_updates(diff_state, updates)
#     207 return diff_state, grads, opt_state, loss_value, aux_data
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\optax\transforms\_combining.py:90, in chain.<locals>.update_fn(updates, state, params, **extra_args)
#      88 new_state = []
#      89 for s, fn in zip(state, update_fns):
# ---> 90   updates, new_s = fn(updates, s, params, **extra_args)
#      91   new_state.append(new_s)
#      92 return updates, tuple(new_state)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\optax\_src\base.py:339, in with_extra_args_support.<locals>.update(***failed resolving arguments***)
#     337 def update(updates, state, params=None, **extra_args):
#     338   del extra_args
# --> 339   return tx.update(updates, state, params)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\optax\_src\transform.py:422, in scale_by_adamax.<locals>.update_fn(***failed resolving arguments***)
#     420 nu = optax.tree.update_infinity_moment(updates, state.nu, b2, eps)
#     421 # Bias correction for mean. No bias correction needed for infinity moment.
# --> 422 mu_hat = optax.tree.bias_correction(mu, b1, count_inc)
#     423 updates = jax.tree.map(lambda m, v: m / v, mu_hat, nu)
#     424 return updates, ScaleByAdamState(count=count_inc, mu=mu, nu=nu)
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\experimental\network_dynamics\core\bunch.py:61, in _bunch_tree_unflatten(keys, values)
#      57     values = tuple(bunch[key] for key in keys)
#      58     return values, keys
# ---> 61 def _bunch_tree_unflatten(keys: Tuple[str, ...], values: Tuple[Any, ...]) -> Bunch:
#      62     """Reconstruct Bunch from keys and values for JAX PyTree."""
#      63     return Bunch(zip(keys, values))
#
# KeyboardInterrupt:

# %% [markdown]
# ### End of test

# %% [markdown]
# ### Visualization of test results

# %%
fc_opt = compute_fc_from_state(optimized_state)
fc_corr_opt = evaluate_trial(optimized_state)['corr']
fc_rmse_opt = evaluate_trial(optimized_state)['rmse']

# Extract loss values
loss_values = optimized_fit["loss"].save
n_steps = len(loss_values)

fig = plt.figure(figsize=(8.1, 6))
gs = fig.add_gridspec(2, 3, hspace=0.3, wspace=0.4)

# Top left: Loss trajectory - use cividis-derived colors
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(loss_values, linewidth=2, color="k", alpha=0.9)
ax1.scatter(0, loss_values[0], s=80, color=accent_blue, zorder=5)
ax1.scatter(n_steps-1, loss_values.array[-1], s=80, color=accent_gold, zorder=5)
ax1.set_xlabel('Optimization Step')
ax1.set_ylabel('Combined Loss')
ax1.set_title('Loss Convergence')
ax1.grid(True, alpha=0.3)

# Top middle: wFFI matrix - use cividis
ax2 = fig.add_subplot(gs[0, 1])
im2 = ax2.imshow(optimized_state.coupling.coupling.wFFI, vmin=0, vmax=2, cmap='cividis')
ax2.set_title('Optimized wFFI')
ax2.set_xlabel('Source')
ax2.set_ylabel('Target')
plt.colorbar(im2, ax=ax2, fraction=0.046)

# Top right: wLRE matrix - use cividis
ax3 = fig.add_subplot(gs[0, 2])
im3 = ax3.imshow(optimized_state.coupling.coupling.wLRE, vmin=0, vmax=2, cmap='cividis')
ax3.set_title('Optimized wLRE')
ax3.set_xlabel('Source')
ax3.set_ylabel('Target')
plt.colorbar(im3, ax=ax3, fraction=0.046)

# Bottom row: FC comparison - use cividis
ax4 = fig.add_subplot(gs[1, 0])
im4 = ax4.imshow(fc_target, vmin=-1, vmax=1.0, cmap='cividis')
ax4.set_title('Target FC')
plt.colorbar(im4, ax=ax4, fraction=0.046)

ax5 = fig.add_subplot(gs[1, 1])
im5 = ax5.imshow(fc_pre_gd, vmin=-1, vmax=1.0, cmap='cividis')
ax5.set_title(f'Pre-Opt FC\nCorr: {fc_corr_pre:.3f}')
plt.colorbar(im5, ax=ax5, fraction=0.046)

ax6 = fig.add_subplot(gs[1, 2])
im6 = ax6.imshow(fc_opt + np.eye(fc_opt.shape[0]), vmin=-1, vmax=1.0, cmap='cividis')
ax6.set_title(f'Post-Opt FC\nCorr: {fc_corr_opt:.3f}')
plt.colorbar(im6, ax=ax6, fraction=0.046)

plt.show()

# %% [markdown]
# ### Compute Q0 and Q1 from empirical and simulated time-series data
#
# **Obs**: We use the notation Q0 and Q1 for the zero lag and 1-TR lag matrices to distinguish from FC0, since they are computed with a different notation.
#
# We have the formulas for Q0 and Q1 are, respectively:
#
# $$ \hat{S_{ij}}(0) = \frac{1}{T-2} \sum_{1 le T-1} [x_i(t) - (\bar{x_i})][x_j(t) - (\bar{x_j})] $$
# $$ \hat{S_{ij}}(1) = \frac{1}{T-2} \sum_{1 le T-1} [x_i(t) - (\bar{x_i})][x_j(t+1) - (\bar{x_j})]$$

# %%
transient_lim = 5  # Number of initial time points to remove from BOLD signal

# get simulated time series
raw_result_gd = model_opt(optimized_state)
bold_result_gd = bold_monitor_opt(raw_result_gd)
bold_signal_gd = bold_result_gd.data
# Reshape from (time points, 1, regions) to (time points, regions) 
n_timepoints_gd, n_nodes_gd = bold_signal_gd.shape[0], bold_signal_gd.shape[-1]
bold_signal_gd = bold_signal_gd.reshape(n_timepoints_gd, n_nodes_gd)
# Remove transient
bold_signal_gd = bold_signal_gd[transient_lim:, :]
print("Simulated BOLD signal shape:", bold_signal_gd.shape)
# Out:
# Simulated BOLD signal shape: (152, 68)

# %%
# Save simulated BOLD signal
np.save(path_simulated_bold, bold_signal_gd)
print(f"Simulated BOLD signal saved to: {path_simulated_bold}")
# Out:
# Simulated BOLD signal saved to: c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\results\simulated_bold_gammaHRF.npy

# %%
# Plot bold signal for empirical and simulated data
time_gd = np.arange(bold_signal_gd.shape[0]) * bold_TR / (1e3*60)
time_emp = np.arange(X_emp.shape[0]) * bold_TR / (1e3*60)

fig, axes = plt.subplots(2, 1, figsize=(12, 8),
                            sharex=True, constrained_layout=True)

axes[0].plot(time_emp, X_emp, alpha=0.3)
axes[0].set_title("Empirical BOLD Signal (all regions)")
axes[0].set_ylabel("BOLD signal")

axes[1].plot(time_gd, bold_signal_gd, alpha=0.3)
axes[1].set_title("Simulated BOLD Signal (all regions)")
axes[1].set_xlabel("Time (min)")
axes[1].set_ylabel("BOLD signal")
plt.show()

# %%
z_scored_emp = z_score_per_region(X_emp)
z_scored_gd = z_score_per_region(bold_signal_gd)

# %%
cmap = plt.cm.PuRd_r
n_nodes = 68
norm = plt.Normalize(vmin=0, vmax=n_nodes - 1)

time_emp = np.arange(z_scored_emp.shape[0]) * bold_TR / (1e3 * 60)
time_gd = np.arange(z_scored_gd.shape[0]) * bold_TR / (1e3 * 60)

# Plot bold signal for empirical and simulated data
fig, axes = plt.subplots(2, 1, figsize=(12, 8),
                            sharex=True, constrained_layout=True)

ax = axes[0]
for roi in range(n_nodes):
	ax.plot(
		time_emp,
		z_scored_emp[:,roi], color=cmap(norm(roi)), lw=1)

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax, pad=0.02)
cbar.set_label('ROI index', fontsize=12)

ax.set_xlim(time_emp.min(), time_emp.max())
ax.set_xlabel('Time (min)', fontsize=16)
ax.set_ylabel('Z-score BOLD activity', fontsize=16)
ax.set_title(f"Z-scored empirical BOLD Signal - participant {participant_idx}, condition {conds[condition_idx]}", fontsize = 16)

ax = axes[1]
for roi in range(n_nodes):
	ax.plot(
		time_gd,
		z_scored_gd[:,roi], color=cmap(norm(roi)), lw=1)

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax, pad=0.02)
cbar.set_label('ROI index', fontsize=12)

ax.set_xlim(time_gd.min(), time_gd.max())
ax.set_xlabel('Time (min)', fontsize=16)
ax.set_ylabel('Z-score BOLD activity', fontsize=16)
ax.set_title(f"Z-scored simulated BOLD Signal (Gamma HRF Kernel) - participant {participant_idx}, condition {conds[condition_idx]}", fontsize = 16)

fig.savefig(os.path.join(run_dir, f'bold_time_series_comparison_gammaHRF.{graph_format}'), dpi=300)

# %%
# Compute empirical lagged FC matrices
Q_emp = lagged_fc_matrices(z_scored_emp, n_tau=2, diag_zero=True)
Q_emp_0 = Q_emp[0]  # FC0 (zero-lag)
Q_emp_1 = Q_emp[1]  # FC1 (lag-1

# Compute simulated lagged FC matrices
Q_sim = lagged_fc_matrices(z_scored_gd, n_tau=2, diag_zero=True)
Q_sim_0 = Q_sim[0]  # Simulated FC0
Q_sim_1 = Q_sim[1]  # Simulated FC1

# %%
# Plot FC 0 and FC 1 for both empirical and simulated data
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
# FC0 - Empirical
im0 = axes[0, 0].imshow(Q_emp_0, vmin=-1, vmax=1, cmap='cividis')
axes[0, 0].set_title('Empirical FC0 (Lag 0)')
plt.colorbar(im0, ax=axes[0, 0], fraction=0.046, pad=0.04)
# FC0 - Simulated
im1 = axes[0, 1].imshow(Q_sim_0, vmin=-1, vmax=1, cmap='cividis')
axes[0, 1].set_title('Simulated FC0 (Lag 0)')
plt.colorbar(im1, ax=axes[0, 1], fraction=0.046, pad=0.04)
# FC1 - Empirical
im2 = axes[1, 0].imshow(Q_emp_1, vmin=-1, vmax=1, cmap='cividis')
axes[1, 0].set_title('Empirical FC1 (Lag 1)')
plt.colorbar(im2, ax=axes[1, 0], fraction=0.046, pad=0.04)
# FC1 - Simulated
im3 = axes[1, 1].imshow(Q_sim_1, vmin=-1, vmax=1, cmap='cividis')
axes[1, 1].set_title('Simulated FC1 (Lag 1)')
plt.colorbar(im3, ax=axes[1, 1], fraction=0.046, pad=0.04)
plt.tight_layout()
plt.show()

# %%
fc0_corr = fc_corr(Q_sim_0, Q_emp_0)
fc1_corr = fc_corr(Q_sim_1, Q_emp_1)

# %%
print(f"FC0 (zero-lag) correlation: {fc0_corr:.4f}")
print(f"FC1 (lag-1) correlation: {fc1_corr:.4f}")
# Out:
# FC0 (zero-lag) correlation: 0.8706
# FC1 (lag-1) correlation: 0.7680

# %% [markdown]
# #### Test 2

# %%
# ---- Two-stage schedule (copy/paste) ----

# Stage 1: fit FC0 only
beta_fc1 = 0.5
max_steps_stage1 = 120
learning_rate_stage1 = 0.0325

def loss_stage1(state):
    ts = model_opt(state)
    bold = bold_monitor_opt(ts)

    bold_signal = bold.data
    n_timepoints, n_nodes = bold_signal.shape[0], bold_signal.shape[-1]
    bold_signal = bold_signal.reshape(n_timepoints, n_nodes)
    bold_signal = bold_signal[5:, :]
    z_scored_bold = z_score_per_region(bold_signal)

    Qsim = lagged_fc_matrices(z_scored_bold, n_tau=2, diag_zero=True)
    Q0_sim, Q1_sim = Qsim[0], Qsim[1]

    loss_q0 = rmse(Q0_sim, Q0_emp)
    loss_q1 = rmse(Q1_sim, Q1_emp)

    mean_activity = jnp.mean(ts.data[-500:, 0, :], axis=0)
    activity_loss = jnp.mean((mean_activity - target_fic) ** 2)

    return loss_q0 + beta_fc1 * loss_q1 + activity_loss

optimizer_stage1 = OptaxOptimizer(
    loss_stage1,
    optax.adamaxw(learning_rate=learning_rate_stage1),
    callback=MultiCallback([DefaultPrintCallback(), SavingLossCallback()])
)

opt_state_stage1, fit_stage1 = optimizer_stage1.run(state_opt, max_steps=max_steps_stage1)

# Stage 2: start from Stage 1 params, add FC1
max_steps_stage2 = 120
learning_rate_stage2 = 0.0325

def loss_stage2(state):
    ts = model_opt(state)
    bold = bold_monitor_opt(ts)

    bold_signal = bold.data
    n_timepoints, n_nodes = bold_signal.shape[0], bold_signal.shape[-1]
    bold_signal = bold_signal.reshape(n_timepoints, n_nodes)
    bold_signal = bold_signal[5:, :]
    z_scored_bold = z_score_per_region(bold_signal)

    Qsim = lagged_fc_matrices(z_scored_bold, n_tau=2, diag_zero=True)
    Q0_sim, Q1_sim = Qsim[0], Qsim[1]

    loss_q0 = rmse(Q0_sim, Q0_emp)
    loss_q1 = rmse(Q1_sim, Q1_emp)

    mean_activity = jnp.mean(ts.data[-500:, 0, :], axis=0)
    activity_loss = jnp.mean((mean_activity - target_fic) ** 2)

    # ramp FC1 weight from 0.2 -> 1.0 over stage 2 steps
    return loss_q0 + loss_q1 + activity_loss

optimizer_stage2 = OptaxOptimizer(
    loss_stage2,
    optax.adamaxw(learning_rate=learning_rate_stage2),
    callback=MultiCallback([DefaultPrintCallback(), SavingLossCallback()])
)

opt_state_stage2, fit_stage2 = optimizer_stage2.run(opt_state_stage1, max_steps=max_steps_stage2)

optimized_state = opt_state_stage2
# Out:
# Step 0: 0.719787
# Step 1: 0.687982
# Step 2: 0.646760
# Step 3: 0.590657
# Step 4: 0.520953
# Step 5: 0.445315
# Step 6: 0.368069
# Step 7: 0.354186
# Step 8: 0.360659
# Step 9: 0.367256
# Step 10: 0.370126
# Step 11: 0.371543
# Step 12: 0.372360
# Step 13: 0.372808
# Step 14: 0.373092
# Step 15: 0.373189
# Step 16: 0.373196
# Step 17: 0.373129
# Step 18: 0.373003
# Step 19: 0.372819
# Step 20: 0.372584
# Step 21: 0.372309
# Step 22: 0.371971
# Step 23: 0.371602
# Step 24: 0.371202
# Step 25: 0.370746
# Step 26: 0.370246
# Step 27: 0.369717
# Step 28: 0.369149
# Step 29: 0.368529
# Step 30: 0.367867
# Step 31: 0.367150
# Step 32: 0.366380
# Step 33: 0.365521
# Step 34: 0.364775
# Step 35: 0.363986
# Step 36: 0.363270
# Step 37: 0.362671
# Step 38: 0.361889
# Step 39: 0.361161
# Step 40: 0.360330
# Step 41: 0.359261
# Step 42: 0.358409
# Step 43: 0.357270
# Step 44: 0.356141
# Step 45: 0.354745
# Step 46: 0.352977
# Step 47: 0.351045
# Step 48: 0.348777
# Step 49: 0.346378
# Step 50: 0.343668
# Step 51: 0.341056
# Step 52: 0.338698
# Step 53: 0.336563
# Step 54: 0.334115
# Step 55: 0.331697
# Step 56: 0.329960
# Step 57: 0.327898
# Step 58: 0.326046
# Step 59: 0.325785
# Step 60: 0.324871
# Step 61: 0.323906
# Step 62: 0.321731
# Step 63: 0.319839
# Step 64: 0.317592
# Step 65: 0.315300
# Step 66: 0.312571
# Step 67: 0.310542
# Step 68: 0.309037
# Step 69: 0.308883
# Step 70: 0.307278
# Step 71: 0.304857
# Step 72: 0.302463
# Step 73: 0.300581
# Step 74: 0.298716
# Step 75: 0.296420
# Step 76: 0.293309
# Step 77: 0.290482
# Step 78: 0.288716
# Step 79: 0.286779
# Step 80: 0.283176
# Step 81: 0.280185
# Step 82: 0.277951
# Step 83: 0.275413
# Step 84: 0.273048
# Step 85: 0.270259
# Step 86: 0.267474
# Step 87: 0.264912
# Step 88: 0.261925
# Step 89: 0.259047
# Step 90: 0.256441
# Step 91: 0.254006
# Step 92: 0.251470
# Step 93: 0.248776
# Step 94: 0.247838
# Step 95: 0.246315
# Step 96: 0.243586
# Step 97: 0.242412
# Step 98: 0.239593
# Step 99: 0.237890
# Step 100: 0.237883
# Step 101: 0.233391
# Step 102: 0.234289
# Step 103: 0.233254
# Step 104: 0.228408
# Step 105: 0.230051
# Step 106: 0.226868
# Step 107: 0.224516
# Step 108: 0.225672
# Step 109: 0.223219
# Step 110: 0.221851
# Step 111: 0.221431
# Step 112: 0.218941
# Step 113: 0.217761
# Step 114: 0.216183
# Step 115: 0.218024
# Step 116: 0.212570
# Step 117: 0.214438
# Step 118: 0.210563
# Step 119: 0.209973
# Step 0: 0.286114
# Step 1: 0.424053
# Step 2: 0.402726
# Step 3: 0.420724
# Step 4: 0.422789
# Step 5: 0.398643
# Step 6: 0.417277
# Step 7: 0.406635
# Step 8: 0.393813
# Step 9: 0.385043
# Step 10: 0.395368
# Step 11: 0.393952
# Step 12: 0.392578
# Step 13: 0.383979
# Step 14: 0.372777
# Step 15: 0.363511
# Step 16: 0.358683
# Step 17: 0.343292
# Step 18: 0.341124
# Step 19: 0.331192
# Step 20: 0.325899
# Step 21: 0.335187
# Step 22: 0.331338
# Step 23: 0.338770
# Step 24: 0.310444
# Step 25: 0.314829
# Step 26: 0.312349
# Step 27: 0.305887
# Step 28: 0.308532
# Step 29: 0.306932
# Step 30: 0.298018
# Step 31: 0.296378
# Step 32: 0.293519
# Step 33: 0.286756
# Step 34: 0.289169
# Step 35: 0.282973
# Step 36: 0.282713
# Step 37: 0.281377
# Step 38: 0.281143
# Step 39: 0.277406
# Step 40: 0.273748
# Step 41: 0.275103
# Step 42: 0.269423
# Step 43: 0.268307
# Step 44: 0.271399
# Step 45: 0.263588
# Step 46: 0.274667
# Step 47: 0.266228
# Step 48: 0.265515
# Step 49: 0.261103
# Step 50: 0.262428
# Step 51: 0.263234
# Step 52: 0.255988
# Step 53: 0.259473
# Step 54: 0.251409
# Step 55: 0.253903
# Step 56: 0.248258
# Step 57: 0.252111
# Step 58: 0.246534
# Step 59: 0.251638
# Step 60: 0.243992
# Step 61: 0.246097
# Step 62: 0.243575
# Step 63: 0.243192
# Step 64: 0.239379
# Step 65: 0.242362
# Step 66: 0.251326
# Step 67: 0.256720
# Step 68: 0.238935
# Step 69: 0.248519
# Step 70: 0.242874
# Step 71: 0.239529
# Step 72: 0.245747
# Step 73: 0.234839
# Step 74: 0.254655
# Step 75: 0.244898
# Step 76: 0.240346
# Step 77: 0.243259
# Step 78: 0.236957
# Step 79: 0.244546
# Step 80: 0.240224
# Step 81: 0.235502
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 69
#      61     return loss_q0 + loss_q1 + activity_loss
#      63 optimizer_stage2 = OptaxOptimizer(
#      64     loss_stage2,
#      65     optax.adamaxw(learning_rate=learning_rate_stage2),
#      66     callback=MultiCallback([DefaultPrintCallback(), SavingLossCallback()])
#      67 )
# ---> 69 opt_state_stage2, fit_stage2 = optimizer_stage2.run(opt_state_stage1, max_steps=max_steps_stage2)
#      71 optimized_state = opt_state_stage2
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\optim\optax.py:213, in OptaxOptimizer.run(self, state, max_steps, mode)
#     211 fitting_data = dict()  # store data during fitting
#     212 for i in range(max_steps):
# --> 213     diff_state, grads, opt_state, loss_value, aux_data = step(
#     214         diff_state, static_state, opt_state
#     215     )
#     216     # print(format_pytree_as_string(diff_state, hide_none=True, name="FreeState", show_array_values=True))
#     217     # print(format_pytree_as_string(diff_state, hide_none=True, name="FreeState", show_array_values=True))
#     218     # fitting_data.append(diff_state)
#     219     if self.callback is not None:
#
# File ~\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\tvboptim\src\tvboptim\optim\optax.py:202, in OptaxOptimizer.run.<locals>.step(diff_state, static_state, opt_state)
#     199 def f(p):
#     200     return _loss(diff_state, static_state)
# --> 202 updates, opt_state = self.optimizer.update(
#     203     grads, opt_state, diff_state, value=loss_value, grad=grads, value_fn=f
#     204 )
#     206 diff_state = optax.apply_updates(diff_state, updates)
#     207 return diff_state, grads, opt_state, loss_value, aux_data
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\optax\transforms\_combining.py:90, in chain.<locals>.update_fn(updates, state, params, **extra_args)
#      88 new_state = []
#      89 for s, fn in zip(state, update_fns):
# ---> 90   updates, new_s = fn(updates, s, params, **extra_args)
#      91   new_state.append(new_s)
#      92 return updates, tuple(new_state)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\optax\_src\base.py:339, in with_extra_args_support.<locals>.update(***failed resolving arguments***)
#     337 def update(updates, state, params=None, **extra_args):
#     338   del extra_args
# --> 339   return tx.update(updates, state, params)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\optax\_src\transform.py:423, in scale_by_adamax.<locals>.update_fn(***failed resolving arguments***)
#     421 # Bias correction for mean. No bias correction needed for infinity moment.
#     422 mu_hat = optax.tree.bias_correction(mu, b1, count_inc)
# --> 423 updates = jax.tree.map(lambda m, v: m / v, mu_hat, nu)
#     424 return updates, ScaleByAdamState(count=count_inc, mu=mu, nu=nu)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\tree.py:155, in map(f, tree, is_leaf, *rest)
#     115 def map(f: Callable[..., Any],
#     116         tree: Any,
#     117         *rest: Any,
#     118         is_leaf: Callable[[Any], bool] | None = None) -> Any:
#     119   """Maps a multi-input function over pytree args to produce a new pytree.
#     120
#     121   Args:
#    (...)    153     - :func:`jax.tree.reduce`
#     154   """
# --> 155   return tree_util.tree_map(f, tree, *rest, is_leaf=is_leaf)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\tree_util.py:361, in tree_map(f, tree, is_leaf, *rest)
#     359 leaves, treedef = tree_flatten(tree, is_leaf)
#     360 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 361 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\tree_util.py:361, in <genexpr>(.0)
#     359 leaves, treedef = tree_flatten(tree, is_leaf)
#     360 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 361 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\optax\_src\transform.py:423, in scale_by_adamax.<locals>.update_fn.<locals>.<lambda>(m, v)
#     421 # Bias correction for mean. No bias correction needed for infinity moment.
#     422 mu_hat = optax.tree.bias_correction(mu, b1, count_inc)
# --> 423 updates = jax.tree.map(lambda m, v: m / v, mu_hat, nu)
#     424 return updates, ScaleByAdamState(count=count_inc, mu=mu, nu=nu)
#
# File c:\Users\Bruna\Documents\Cogmaster\M2\Stage\scripts\TVBOptim\.venv\Lib\site-packages\jax\_src\numpy\array_methods.py:604, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     602 args = (other, self) if swap else (self, other)
#     603 if isinstance(other, _accepted_binop_types):
# --> 604   return binary_op(*args)
#     605 # Note: don't use isinstance here, because we don't want to raise for
#     606 # subclasses, e.g. NamedTuple objects that may override operators.
#     607 if type(other) in _rejected_binop_types:
#
# KeyboardInterrupt:
